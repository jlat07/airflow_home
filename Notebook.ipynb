# %%
import pandas as pd
import os
import json

# %% [markdown]
# ## Read csv

# %%
#Standard Data that you see on Oura Home screen from the data show in data2

data = pd.read_csv('/Users/jthompson/dev/airflow_home/data/oura_2019_trends.csv')

# %%
data2 = pd.read_csv('/Users/jthompson/dev/airflow_home/data/oura_2019-09-17_2020-04-01_trends.csv')

# %% [markdown]
# Display the contents of the DataFrame.

# %%
df = pd.DataFrame(data)

# %%
df2 = pd.DataFrame(data2)

# %%
df
# Out:
#            date  average_rhr  sleep_score  activity_score  readiness_score
# 0    2018-12-17          NaN          NaN            93.0              NaN
# 1    2018-12-18       59.750         84.0            99.0             93.0
# 2    2018-12-19       57.375         75.0            98.0             68.0
# 3    2018-12-20       52.625         82.0            98.0             87.0
# 4    2018-12-21       57.375         80.0            96.0             82.0
# ..          ...          ...          ...             ...              ...
# 295  2019-12-28       76.240         53.0            90.0             36.0
# 296  2019-12-29       64.040         80.0            91.0             80.0
# 297  2019-12-30       56.920         73.0            90.0             81.0
# 298  2019-12-31          NaN          NaN            78.0             87.0
# 299  2020-01-01       73.450         61.0            75.0             58.0
#
# [300 rows x 5 columns]

# %%
df2
# Out:
#            date  Sleep Score  Total Sleep Score  REM Sleep Score  \
# 0    2019-09-17         67.0               76.0             25.0
# 1    2019-09-18         78.0               87.0             56.0
# 2    2019-09-19         72.0               82.0             58.0
# 3    2019-09-20         59.0               54.0             41.0
# 4    2019-09-21         48.0               46.0             27.0
# ..          ...          ...                ...              ...
# 189  2020-03-27         67.0               79.0             50.0
# 190  2020-03-28         57.0               71.0             47.0
# 191  2020-03-29         57.0               65.0             52.0
# 192  2020-03-30         45.0               21.0              7.0
# 193  2020-03-31         61.0               61.0             41.0
#
#      Deep Sleep Score  Sleep Efficiency Score  Sleep Tranquility Score  \
# 0                23.0                    95.0                     61.0
# ...

# %% [markdown]
# What is the shape of the DataFrame? Does this match the number of columns and records you expected?

# %%
df.iloc[1]
# Out:
# date               2018-12-18
# average_rhr             59.75
# sleep_score                84
# activity_score             99
# readiness_score            93
# Name: 1, dtype: object

# %%
df2.shape
# Out:
# (194, 56)

# %% [markdown]
# Show the first few records of the DataFrame.

# %%
# Show the first few records
df.head()
# Out:
#          date  average_rhr  sleep_score  activity_score  readiness_score
# 0  2018-12-17          NaN          NaN            93.0              NaN
# 1  2018-12-18       59.750         84.0            99.0             93.0
# 2  2018-12-19       57.375         75.0            98.0             68.0
# 3  2018-12-20       52.625         82.0            98.0             87.0
# 4  2018-12-21       57.375         80.0            96.0             82.0

# %% [markdown]
# Show the last few records of the DataFrame.

# %%
# Show the last few records
df.tail()

# %%
df.iloc[1]

# %% [markdown]
# ## Validate Records Are Unique

# %% [markdown]
# Provide two different ways to determine there are no duplicate records.
# Hint: The id field should be unique.

# %%
# one day to determine there are not duplicate records
id_duplicate = df['date'].duplicated()
df[id_duplicate == True]
# Out:
# Empty DataFrame
# Columns: [date, average_rhr, sleep_score, activity_score, readiness_score]
# Index: []

# %%
# another way to determine there are no duplicate records
pd.Series(df['date']).is_unique
# Out:
# True

# %% [markdown]
# # Peking In

# %% [markdown]
# Show the record with date "2019-02-28".

# %%
df[df['date'] == "2019-02-28"]
# Out:
#           date  average_rhr  sleep_score  activity_score  readiness_score
# 47  2019-02-28          NaN          NaN            93.0             82.0

# %% [markdown]
# How many unique values are there for the average_rhr in the DataFrame?

# %%
df.groupby('average_rhr').nunique()
# Out:
#              date  average_rhr  sleep_score  activity_score  readiness_score
# average_rhr
# 45.750          1            1            1               1                1
# 47.750          1            1            1               1                1
# 48.250          2            1            2               2                2
# 48.375          1            1            1               1                1
# 48.750          3            1            2               3                3
# ...           ...          ...          ...             ...              ...
# 79.500          1            1            1               1                1
# 82.375          1            1            1               1                1
# 86.000          1            1            1               1                1
# 88.000          1            1            1               1                1
# 88.970          1            1            1               1                1
#
# [171 rows x 5 columns]
